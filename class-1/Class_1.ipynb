# %%
'''
print("Hello World")
'''
"""
print("Hello World")
"""
name = input("Enetr Name: ") # this our input funtion
print("How are you? " + name + ". Have a nice day.")
# Out:
# Enetr Name: Hasib
# How are you? Hasib. Have a nice day.

# %%
age = input("Enter Age: ")
name = input("Enter Name: ")
print("Dear " + name + " your age is " + age + ".")
# Out:
# Enter Age: 24
# Enter Name: Hasib
# Dear Hasib your age is 24.

# %%
number1 = input("Enter First Number: ")
number2 = input("Enter Second Number: ")
print("Sum: ", int(number1) + int(number2))
# Out:
# Enter First Number: 6
# Enter Second Number: 8
# Sum:  14

# %%
print("Hi"); print("Hello") # separator
# Out:
# Hi
# Hello
